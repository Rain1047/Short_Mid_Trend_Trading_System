# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
import json
import sqlite3 as sql

# %%
database = "../dataset/us/ticker_symbol_us.db"
con = sql.connect(database)
con.row_factory = sql.Row
cur = con.cursor()
cur.execute('Select * from TOTAL')
rows = cur.fetchall()

# %%
rows
# Out:
# ...
#  ...]

# %%
for row in rows:
    print(row['Ticker'])
# Out:
# AAOI
# AAPL
# AATC
# ABST
# ACIW
# ACLS
# ACMR
# ACVA
# ADBE
# ADI
# ADSK
# ADTN
# AEHR
# AEY
# AEYE
# AFRM
# AGIL
# AGMH
# AGYS
# AHI
# AIP
# AIRG
# AKAM
# AKTS
# ALF
# ALGM
# ALKT
# ALLT
# ALOT
# ALRM
# ALTR
# ALYA
# AMAT
# AMBA
# AMD
# AMKR
# AMOT
# AMPG
# AMPL
# AMST
# AMSWA
# ANSS
# ANY
# AOSL
# APCX
# API
# APP
# APPF
# APPN
# APPS
# ARBE
# ARQQ
# ARRY
# ASML
# ASUR
# ASYS
# ATOM
# AUDC
# AUID
# AUR
# AUUD
# AVCT
# AVDX
# AVGO
# AVNW
# AVPT
# AVT
# AWRE
# AXTI
# AZPN
# BAND
# BASE
# BCOV
# BEEM
# BELFB
# BIGC
# BL
# BLBX
# BLIN
# BLKB
# BLZE
# BMBL
# BNFT
# BNSO
# BOSC
# BOXL
# BRQS
# BRZE
# BSQR
# BSY
# BTRS
# CAMP
# CAMT
# CAN
# CASA
# CCMP
# CCSI
# CD
# CDK
# CDNS
# CDW
# CEVA
# CFLT
# CGNT
# CGNX
# CHKP
# CIH
# CISO
# CLBT
# CLFD
# CLPS
# CLRO
# CLSK
# CMBM
# CMTL
# CNDT
# CNXC
# CNXN
# COHU
# COIN
# COMM
# CORZ
# COUP
# CPSH
# CPTN
# CRCT
# CRDO
# CREX
# CRGE
# CRNC
# CRNT
# CRSR
# CRUS
# CRWD
# CSCO
# CSGS
# CSIQ
# CSPI
# CTG
# CTLP
# CTSH
# CTXS
# CUEN
# CVLT
# CVT
# ...
