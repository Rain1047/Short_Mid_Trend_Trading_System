# %%
# import pyfinance
from pyfinviz.screener import Screener

# with no params (default screener table)
screener = Screener()
# with params (The first 3 pages of "STOCKS ONLY" where Analyst recommend a strong buy)
options = [Screener.IndustryOption.STOCKS_ONLY_EX_FUNDS, Screener.AnalystRecomOption.STRONG_BUY_1]
screener = Screener(filter_options=options, view_option=Screener.ViewOption.VALUATION,
                    pages=[x for x in range(1, 4)])

# %%
screener

# %%
screener.data_frames[0]
# Out:
#     No Ticker MarketCap     PE  FwdPE   PEG      PS     PB      PC   PFCF  \
# 0    1   AACG    36.30M      -      -     -    1.17   1.57    3.90      -
# 1    2   ACET   707.36M      -      -     -   18.28   2.38       -      -
# 2    3   ACIU   281.60M      -      -     -       -   1.15    1.38      -
# 3    4   ACLX   874.43M      -      -     -       -   1.89    4.14      -
# 4    5   ACRS     1.11B      -      -     -  173.23   5.58    6.17      -
# 5    6   ACST    50.82M      -      -     -       -   0.24    0.90      -
# 6    7    ACU   112.41M  10.00   9.91  1.00    0.62   1.42   21.21      -
# 7    8   ADMA   441.81M      -      -     -    4.70   3.55    6.36      -
# 8    9    ADN   144.00M      -      -     -   21.18   1.08    2.43      -
# 9   10   ADUS     1.40B  31.48  21.07  2.10    1.58   2.37   11.22  23.69
# 10  11     AE   139.03M   9.18  13.51     -    0.06   0.84    1.40   3.17
# 11  12    AFT   198.87M  10.06      -     -    9.54   0.78       -      -
# 12  13   AGEN   691.89M      -      -     -    2.23  45.17    2.63      -
# 13  14   AGIL   265.50M      -      -     -    1.60   2.75  106.20      -
# 14  15    AGM     1.05B   8.84   8.06  0.80    2.42   1.49    1.19   3.44
# 15  16   AHCO     2.59B  14.48  12.87  1.04    0.97   1.23   21.66      -
# 16  17    AIV     1.03B      -      -     -    5.71   1.94    9.43      -
# 17  18   ALBO   452.02M      -      -     -    9.96   3.20    2.09      -
# 18  19   ALDX   253.01M      -      -     -       -   1.37    1.17      -
# 19  20   ALLR    11.89M      -      -     -       -   0.76       -      -
#
#     EPSthisY EPSnextY EPSpast5Y EPSnext5Y Salespast5Y  Price   Change  \
# 0     63.50%  -23.40%   -22.00%    25.00%     -15.60%   1.35    6.30%
# 1     60.00%  -88.00%         -    29.10%           -  16.74  -10.03%
# 2    -13.10%   66.30%   -47.00%         -           -   3.33   -0.60%
# 3   -102.40%   11.00%         -         -           -  20.47    1.39%
# 4    -33.20%    2.70%     6.50%         -           -  15.64   -4.28%
# 5     79.90%   20.80%    49.50%         -           -   0.91    1.39%
# 6     49.60%   33.19%    16.10%    10.00%       7.90%  30.65   -2.39%
# 7     41.60%   54.80%    20.40%         -      50.00%   2.25   -2.60%
# 8   -561.80%   25.60%         -         -           -   2.47   -9.01%
# 9     35.30%   12.65%    21.50%    15.00%      16.60%  88.00    0.42%
# 10    28.70%  -33.29%    35.80%         -      13.00%  31.39   -1.79%
# 11         -        -         -         -           -  12.78    0.08%
# 12    90.00%   28.10%    40.90%         -      67.30%   2.63   -2.77%
# 13    13.80%   49.10%         -         -           -   5.28   -1.12%
# 14    20.00%   10.33%    10.70%    11.00%       6.70%  97.86   -0.28%
# 15   134.60%   29.06%         -    13.94%           -  19.24   -1.05%
# 16   -16.50%        -   -15.00%     7.10%     -29.80%   6.62    0.00%
# 17    73.70%   37.50%    33.10%         -      29.00%  23.43   -4.37%
# 18     3.30%   -7.50%     8.30%         -           -   4.57    1.67%
# 19  -412.60%   45.20%         -         -           -   1.32   -2.22%
#
#        Volume
# 0      20,064
# 1     496,989
# 2      22,923
# 3     127,767
# 4     225,887
# 5      32,162
# 6       2,142
# 7   2,374,525
# 8     868,759
# 9      37,786
# 10      6,347
# 11     49,509
# 12  2,835,229
# 13      3,763
# 14     12,776
# 15    361,241
# 16    576,740
# 17    105,975
# 18    477,619
# 19     33,308

# %%
data = screener.data_frames[1]
data

# %%
screener.data_frames[2]
# Out:
#     No Ticker MarketCap     PE  FwdPE   PEG      PS    PB      PC   PFCF  \
# 0   21   ALPN   284.83M      -      -     -    8.40  2.41    1.66  46.69
# 1   22  AMSWA   583.11M  45.94  33.58  2.87    4.57  4.32    4.57  43.19
# 2   23   ANTX   169.82M      -      -     -       -  0.25    1.44      -
# 3   24   ANVS   122.43M      -      -     -       -  2.84    2.87      -
# 4   25   APEI   281.96M  18.95  12.96  1.26    0.58  0.67    1.65  16.59
# 5   26   APRN   153.32M      -      -     -    0.33  2.87    2.74      -
# 6   27    APT    57.81M  13.05      -  0.87    0.92  0.92       -      -
# 7   28   AQMS    57.68M      -  10.50     -  288.38  2.07    6.41      -
# 8   29    ARC   112.90M  10.79   9.96  1.08    0.40  0.71    2.24   4.61
# 9   30   ARDC   278.19M   7.49      -     -       -     -       -      -
# 10  31   ARKO     1.07B  16.30  14.34     -    0.14  4.48    3.57      -
# 11  32  ARTNA   462.67M  27.81  23.12  6.95    5.01  2.63  925.34      -
# 12  33   ASAI     3.75B  13.08   2.63  0.23    0.46  6.96    4.57  13.69
# 13  34    ASC   236.79M      -  33.05     -    1.13  0.83    4.45      -
# 14  35   ATXS    45.61M      -      -     -       -  3.65    0.40      -
# 15  36   AURA   447.68M      -      -     -       -  3.14    3.36      -
# 16  37   AUVI    27.11M      -      -     -    2.13  0.96    3.82      -
# 17  38   AVDL   250.92M      -      -     -       -  4.64    2.03      -
# 18  39   AVEO   249.59M      -      -     -    4.07  6.70    3.16      -
# 19  40   AVTE   378.15M      -      -     -       -  2.65    2.35      -
#
#     EPSthisY EPSnextY EPSpast5Y EPSnext5Y Salespast5Y  Price   Change  \
# 0    -47.30%  -85.70%     2.00%         -      51.40%   9.09   -1.25%
# 1     52.70%   45.85%    -4.00%    16.00%       3.70%  17.18    0.53%
# 2    -92.40%  -17.30%         -         -           -   8.00  -11.01%
# 3   -119.40%    3.50%         -         -           -  14.40   -1.44%
# 4    -22.30%   41.81%    -8.20%    15.00%       6.00%  14.73   -2.00%
# 5    -29.70%   64.80%     1.80%         -     -10.00%   4.09  -12.42%
# 6    -74.00%        -    21.60%    15.00%       8.30%   4.43   -0.45%
# 7     38.60%  130.40%    21.80%    35.00%           -   0.78   -0.47%
# 8     48.70%    0.00%    17.10%    10.00%      -7.70%   2.59    0.00%
# 9          -        -         -         -           -  12.07   -0.58%
# 10   190.40%   12.22%         -         -      27.30%   8.59   -1.15%
# 11    -0.50%   14.74%     4.80%     4.00%       2.80%  49.57   -1.65%
# 12    55.90%   91.02%         -    55.70%           -  14.27   -0.97%
# 13  -518.00%  -81.08%   -61.70%    42.64%       3.20%   6.76   -2.52%
# 14  -101.50%   14.00%    28.70%         -           -   3.68   -1.08%
# 15   -49.10%   11.30%         -         -           -  14.46   -4.55%
# 16   -46.10%   34.00%         -         -           -   2.25   -5.46%
# 17   -21.20%  102.50%    -5.70%    15.00%           -   4.76    9.17%
# 18     1.80%   88.80%    15.90%         -      75.90%   6.80   -5.23%
# 19  -135.40%  -19.50%         -         -           -  15.46  -12.06%
#
#        Volume
# 0      17,532
# 1      47,081
# 2      43,455
# 3     126,046
# 4      10,477
# 5   2,813,920
# 6      47,831
# 7     214,537
# 8      42,945
# 9      58,479
# 10     69,381
# 11     13,948
# 12     62,319
# 13    181,921
# 14    106,043
# 15     32,659
# 16    136,369
# 17  1,049,753
# 18    179,764
# 19     33,850

# %%
screener.data_frames[3]
# Out:
#     No Ticker MarketCap     PE   FwdPE   PEG      PS    PB      PC   PFCF  \
# 0   41    AWH   103.70M      -       -     -   14.40  5.32    3.85      -
# 1   42   BARK   247.20M      -       -     -    0.49  1.10    1.24      -
# 2   43   BBCP   349.61M  25.12   11.34     -    1.00  1.28  124.86  26.89
# 3   44   BBDC   620.50M   6.55    9.60  1.31    4.58  0.83       -      -
# 4   45   BBGI    38.20M   7.14       -     -    0.15  0.15    0.75      -
# 5   46    BBI     9.98M      -       -     -   19.97  0.63    0.58      -
# 6   47   BBVA    28.37B   6.02    5.41  0.15    2.09  0.68    0.14      -
# 7   48   BCEL    87.20M      -       -     -       -  0.71    0.74      -
# 8   49    BFI    70.00M      -       -     -    0.68  0.43    5.26      -
# 9   50   BFST   487.18M   9.18    7.26     -    2.86  0.99    1.31  12.03
# 10  51    BIO    15.27B      -   33.19     -    5.27  1.52    7.36  33.27
# 11  52   BIOR   127.10M      -       -     -  105.91     -    1.89      -
# 12  53   BIOS   290.76M      -   31.00     -       -  1.32  726.89      -
# 13  54   BLCM    10.41M      -       -     -    1.68  2.04    0.26      -
# 14  55   BLFY   348.48M      -  110.00     -    6.26  0.76    3.12      -
# 15  56   BLRX    63.11M      -       -     -       -  1.11    1.25      -
# 16  57    BLX   484.83M   8.37    6.23  0.99    3.17  0.49    0.27      -
# 17  58   BMRA    37.39M      -   73.25     -    2.56  3.86    3.67  13.85
# 18  59   BNGO   478.00M      -       -     -   23.32  1.50    2.21      -
# 19  60   BOOM   360.33M      -    8.27     -    1.05  1.06       -      -
#
#     EPSthisY  EPSnextY EPSpast5Y EPSnext5Y Salespast5Y   Price   Change  \
# 0    -60.20%    14.80%     0.10%         -      20.90%    0.87  -13.71%
# 1   -157.80%    30.30%         -         -           -    1.30   -5.62%
# 2     73.70%    42.78%         -         -           -    6.27   -0.16%
# 3      6.70%     3.10%   -26.25%     5.00%           -    9.44   -0.63%
# 4     92.30%  -100.00%   -15.10%         -      12.10%    1.31   -0.76%
# 5     42.40%    -5.00%    39.90%         -     -51.20%    3.68   -4.17%
# 6     32.00%    13.90%     4.20%    40.10%      -3.60%    4.30   -3.27%
# 7     -9.10%     9.20%         -         -           -    2.32  -10.27%
# 8          -         -         -         -           -    3.18   -2.15%
# 9     53.70%    23.08%    29.30%         -      31.50%   21.29   -0.93%
# 10    11.40%     7.41%   176.00%    17.80%       7.20%  524.04    1.34%
# 11    51.50%    11.90%         -         -           -    0.71    2.81%
# 12    63.30%   277.80%    -9.93%    10.00%           -    9.92    0.00%
# 13    37.10%    29.10%    49.50%         -      74.10%    1.12   -3.45%
# 14  -170.30%   266.67%         -         -           -   11.83   -2.23%
# 15    65.60%    11.90%         -         -           -    1.42   -3.48%
# 16     0.80%    16.13%    -6.20%     8.47%     -10.50%   13.36   -0.74%
# 17  -137.00%   109.30%   -26.00%         -       7.00%    3.00    2.39%
# 18    33.60%     5.10%    33.30%         -      21.50%    1.53   -5.83%
# 19  -175.10%  1038.05%    10.60%    20.00%      10.40%   19.02   -1.45%
#
#        Volume
# 0     426,723
# 1     621,149
# 2      15,085
# 3     232,886
# 4       1,913
# 5     507,572
# 6   1,885,142
# 7     151,069
# 8      20,795
# 9       9,338
# 10    181,608
# 11  1,984,734
# 12         66
# 13     19,703
# 14     33,573
# 15     63,995
# 16     31,436
# 17     58,680
# 18  2,750,608
# 19     90,971

# %%
ExchangeList = [
    'Screener.ExchangeOption.NASDAQ',
    'Screener.ExchangeOption.NYSE',
    'Screener.ExchangeOption.AMEX'
]

# %%
ExchangeList = [
    Screener.ExchangeOption.NASDAQ,
    Screener.ExchangeOption.NYSE,
    Screener.ExchangeOption.AMEX
]

# %%
for exchange in ExchangeList:
    option = [exchange]
    print(exchange)
    print(option)
# Out:
# ExchangeOption.NASDAQ
# [<ExchangeOption.NASDAQ: 'exch_nasd'>]
# ExchangeOption.NYSE
# [<ExchangeOption.NYSE: 'exch_nyse'>]
# ExchangeOption.AMEX
# [<ExchangeOption.AMEX: 'exch_amex'>]

# %%
for i in range(3):
    temp = [ExchangeList[i].value]
    # temp.append(ExchangeList[i])
    print(temp)
# Out:
# ['exch_nasd']
# ['exch_nyse']
# ['exch_amex']

# %%
# import pyfinance
from pyfinviz.screener import Screener
# with no params (default screener table)
screener = Screener()
# NASDAQ Technology
options = [Screener.ExchangeOption.NASDAQ, Screener.SectorOption.TECHNOLOGY]
screener = Screener(filter_options=options, view_option=Screener.ViewOption.VALUATION,
                    pages=[x for x in range(1, 30)])

# %%
len_ = len(screener.data_frames)

# %%
df_ = screener.data_frames[0].append(screener.data_frames[1])
# Out:
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\56825604.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_ = screener.data_frames[0].append(screener.data_frames[1])

# %%
screener.data_frames[28].shape[0]
# Out:
# 12

# %%
df_
# Out:
#     No Ticker MarketCap      PE  FwdPE      PEG      PS     PB      PC  \
# 0    1   AAOI    41.22M       -      -        -    0.19   0.17    1.29
# 1    2   AAPL  2333.74B   23.55  22.14     2.38    6.05  34.99   45.31
# 2    3   AATC    28.25M   23.80      -     1.19    2.17   1.46    5.88
# 3    4   ABST   576.81M       -      -        -    2.52  42.38    6.44
# 4    5   ACIW     3.12B   22.06  17.35     1.84    2.22   2.56   27.20
# 5    6   ACLS     1.65B   14.07  10.63     0.70    2.25   3.04    5.56
# 6    7   ACMR   913.52M   26.80  17.31     0.63    3.54   1.39    1.90
# 7    8   ACVA     1.07B       -      -        -    2.73   2.00    1.71
# 8    9   ADBE   180.46B   37.52  24.24     2.64   10.81  12.97   34.05
# 9   10    ADI    76.00B   41.86  14.87     2.24    7.79   2.08   43.74
# 10  11   ADSK    38.91B   80.18  22.43     3.18    8.52  56.28   24.55
# 11  12   ADTN   967.25M       -  18.14        -    1.64   2.80   17.78
# 12  13   AEHR   195.46M   47.66  10.64     2.38    5.12   4.48    6.11
# 13  14    AEY    17.57M       -      -        -    0.22   2.06    4.50
# 14  15   AEYE    67.03M       -      -        -    2.62   4.46    5.59
# 15  16   AFRM     6.19B       -      -        -    5.82   2.37    2.74
# 16  17   AGIL   260.53M       -      -        -    1.57   2.70  104.21
# 17  18   AGMH    45.37M   11.61      -        -    1.24   1.64    2.47
# 18  19   AGYS     1.25B  272.14  47.62  5442.86    7.66  12.44   12.84
# 19  20    AHI    14.36M       -      -        -  237.72   1.08       -
#
#       PFCF  EPSthisY EPSnextY EPSpast5Y EPSnext5Y Salespast5Y   Price  Change  \
# 0        -    24.70%   55.20%   -25.70%    13.00%      -4.10%    1.50  -7.98%
# 1    25.63    71.40%    6.67%    22.00%     9.91%      11.10%  144.87  -1.48%
# 2        -   114.20%        -    25.80%    20.00%      -1.30%    5.26  -1.15%
# 3    15.38   -68.50%   76.10%   -20.80%         -       6.30%    8.90  -6.51%
# 4    19.43    75.00%   17.67%    -0.20%    12.00%       6.40%   27.16   0.18%
# 5    10.87    96.60%    9.02%    51.90%    20.00%      19.90%   51.10  -2.24%
# 6        -   -34.80%   38.88%    68.40%    42.74%      56.80%   15.89  -6.20%
# 7   198.74  -134.40%   26.80%         -     0.80%           -    6.85  -5.26%
# 8    26.31    -7.60%   17.23%    34.00%    14.23%      21.90%  384.16  -1.36%
# 9    41.85     5.60%    7.10%     4.70%    18.71%      16.40%  147.56  -1.59%
# 10   24.61   -58.80%   20.38%    23.40%    25.20%      16.60%  176.72  -1.73%
# 11       -  -460.90%   78.55%   -17.60%     2.30%      -2.40%   20.08  -2.33%
# 12  102.88    29.40%   60.47%    30.10%    20.00%       2.70%    7.34  -2.65%
# 13   19.52    66.20%        -     6.22%         -      10.00%    1.32   1.54%
# 14       -   -67.10%   16.00%    11.90%         -      89.80%    5.89  -7.54%
# 15       -  -208.70%   15.50%         -         -           -   21.37  -8.44%
# 16       -    13.80%   49.10%         -         -           -    5.24  -1.87%
# 17       -   427.90%        -    27.00%         -      39.80%    1.87  -1.58%
# 18   45.63   118.10%   25.76%    18.70%     0.05%       5.00%   49.53  -1.26%
# 19       -         -        -         -         -           -    0.60  -0.59%
#
#         Volume
# 0      131,523
# 1   63,305,112
# 2       10,187
# 3       41,274
# 4      658,496
# 5      157,776
# 6      517,393
# 7      783,006
# 8    1,835,865
# 9    2,688,810
# 10     992,782
# 11   2,932,586
# 12     455,094
# 13       2,967
# 14      15,325
# 15  11,502,552
# 16       5,042
# 17      20,808
# 18      77,219
# 19      44,164

# %%
len_ = len(screener.data_frames)
for i in range(len_):
    if i == 0:
        df = screener.data_frames[i]
    elif i!=1 and screener.data_frames[i].shape[0] > 1:
        df = df.append(screener.data_frames[i])
# Out:
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\2001955443.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\2001955443.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\2001955443.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\2001955443.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\2001955443.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\2001955443.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\2001955443.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\2001955443.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\2001955443.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\2001955443.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\2001955443.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\2001955443.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\2001955443.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\2001955443.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\2001955443.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\2001955443.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\2001955443.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\2001955443.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\2001955443.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\2001955443.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\2001955443.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\2001955443.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\2001955443.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\2001955443.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\2001955443.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\2001955443.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])

# %%
df.index = range(len(df))

# %%
import pandas as pd
df_nasdaq = pd.DataFrame()
df_nasdaq['Ticker'] = df.Ticker
df_nasdaq['Sector'] = 'Technology'
df_nasdaq['Exchange'] = 'NASDAQ'

df_nasdaq
# Out:
#     Ticker      Sector Exchange
# 0     AAOI  Technology   NASDAQ
# 1     AAPL  Technology   NASDAQ
# 2     AATC  Technology   NASDAQ
# 3     ABST  Technology   NASDAQ
# 4     ACIW  Technology   NASDAQ
# ..     ...         ...      ...
# 547    XRX  Technology   NASDAQ
# 548   ZBRA  Technology   NASDAQ
# 549   ZENV  Technology   NASDAQ
# 550     ZI  Technology   NASDAQ
# 551     ZS  Technology   NASDAQ
#
# [552 rows x 3 columns]

# %%
# import pyfinance
from pyfinviz.screener import Screener

# %%
# NASDAQ Energy
options = [Screener.ExchangeOption.NASDAQ, Screener.SectorOption.ENERGY]
screener = Screener(filter_options=options, view_option=Screener.ViewOption.VALUATION,
                    pages=[x for x in range(1, 5)])
# get screener
len_ = len(screener.data_frames)
for i in range(len_):
    if i == 0:
        df = screener.data_frames[i]
    elif i!=1 and screener.data_frames[i].shape[0] > 1:
        df = df.append(screener.data_frames[i])
# create temp list
df_ = pd.DataFrame()
df_['Ticker'] = df.Ticker
df_['Sector'] = 'Energy'
df_['Exchange'] = 'NASDAQ'

df_nasdaq = df_nasdaq.append(df_)
df_nasdaq.index = range(len(df_nasdaq))
# Out:
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\49738479.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\49738479.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_nasdaq = df_nasdaq.append(df_)

# %%
df_nasdaq
# Out:
#     Ticker      Sector Exchange
# 0     AAOI  Technology   NASDAQ
# 1     AAPL  Technology   NASDAQ
# 2     AATC  Technology   NASDAQ
# 3     ABST  Technology   NASDAQ
# 4     ACIW  Technology   NASDAQ
# ..     ...         ...      ...
# 606   VIVK      Energy   NASDAQ
# 607   VNOM      Energy   NASDAQ
# 608   VTNR      Energy   NASDAQ
# 609   WFRD      Energy   NASDAQ
# 610   ZEST      Energy   NASDAQ
#
# [611 rows x 3 columns]

# %%
# NASDAQ Basic_Materials
options = [Screener.ExchangeOption.NASDAQ, Screener.SectorOption.BASIC_MATERIALS]
screener = Screener(filter_options=options, view_option=Screener.ViewOption.VALUATION,
                    pages=[x for x in range(1, 5)])
# get screener
len_ = len(screener.data_frames)
for i in range(len_):
    if i == 0:
        df = screener.data_frames[i]
    elif i!=1 and screener.data_frames[i].shape[0] > 1:
        df = df.append(screener.data_frames[i])
# create temp list
df_ = pd.DataFrame()
df_['Ticker'] = df.Ticker
df_['Sector'] = 'Basic_Materials'
df_['Exchange'] = 'NASDAQ'

df_nasdaq = df_nasdaq.append(df_)
df_nasdaq.index = range(len(df_nasdaq))
# Out:
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\3355109551.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\3355109551.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_nasdaq = df_nasdaq.append(df_)

# %%
df_nasdaq
# Out:
#     Ticker           Sector Exchange
# 0     AAOI       Technology   NASDAQ
# 1     AAPL       Technology   NASDAQ
# 2     AATC       Technology   NASDAQ
# 3     ABST       Technology   NASDAQ
# 4     ACIW       Technology   NASDAQ
# ..     ...              ...      ...
# 665   WDFC  Basic_Materials   NASDAQ
# 666   YTEN  Basic_Materials   NASDAQ
# 667   ZEUS  Basic_Materials   NASDAQ
# 668   ZKIN  Basic_Materials   NASDAQ
# 669     ZY  Basic_Materials   NASDAQ
#
# [670 rows x 3 columns]

# %%
# NASDAQ Financial
options = [Screener.ExchangeOption.NASDAQ, Screener.SectorOption.FINANCIAL]
screener = Screener(filter_options=options, view_option=Screener.ViewOption.VALUATION,
                    pages=[x for x in range(1, 65)])
# get screener
len_ = len(screener.data_frames)
for i in range(len_):
    if i == 0:
        df = screener.data_frames[i]
    elif i!=1 and screener.data_frames[i].shape[0] > 1:
        df = df.append(screener.data_frames[i])
# create temp list
df_ = pd.DataFrame()
df_['Ticker'] = df.Ticker
df_['Sector'] = 'Financial'
df_['Exchange'] = 'NASDAQ'

df_nasdaq = df_nasdaq.append(df_)
df_nasdaq.index = range(len(df_nasdaq))
# Out:
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\4066945386.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\4066945386.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\4066945386.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\4066945386.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\4066945386.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\4066945386.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\4066945386.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\4066945386.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\4066945386.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\4066945386.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\4066945386.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\4066945386.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\4066945386.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\4066945386.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\4066945386.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\4066945386.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\4066945386.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\4066945386.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\4066945386.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\4066945386.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\4066945386.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\4066945386.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\4066945386.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\4066945386.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\4066945386.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\4066945386.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\4066945386.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\4066945386.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\4066945386.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\4066945386.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\4066945386.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\4066945386.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\4066945386.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\4066945386.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\4066945386.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\4066945386.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\4066945386.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\4066945386.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\4066945386.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\4066945386.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\4066945386.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\4066945386.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\4066945386.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\4066945386.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\4066945386.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\4066945386.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\4066945386.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\4066945386.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\4066945386.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\4066945386.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\4066945386.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\4066945386.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\4066945386.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\4066945386.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\4066945386.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\4066945386.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\4066945386.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\4066945386.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\4066945386.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\4066945386.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\4066945386.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_nasdaq = df_nasdaq.append(df_)

# %%
df_nasdaq
# Out:
#      Ticker      Sector Exchange
# 0      AAOI  Technology   NASDAQ
# 1      AAPL  Technology   NASDAQ
# 2      AATC  Technology   NASDAQ
# 3      ABST  Technology   NASDAQ
# 4      ACIW  Technology   NASDAQ
# ...     ...         ...      ...
# 1890   YLDE   Financial   NASDAQ
# 1891   ZING   Financial   NASDAQ
# 1892   ZION   Financial   NASDAQ
# 1893     ZT   Financial   NASDAQ
# 1894  ZWRKU   Financial   NASDAQ
#
# [1895 rows x 3 columns]

# %%
# NASDAQ Healthcare
options = [Screener.ExchangeOption.NASDAQ, Screener.SectorOption.HEALTHCARE]
screener = Screener(filter_options=options, view_option=Screener.ViewOption.VALUATION,
                    pages=[x for x in range(1, 65)])
# get screener
len_ = len(screener.data_frames)
for i in range(len_):
    if i == 0:
        df = screener.data_frames[i]
    elif i!=1 and screener.data_frames[i].shape[0] > 1:
        df = df.append(screener.data_frames[i])
# create temp list
df_ = pd.DataFrame()
df_['Ticker'] = df.Ticker
df_['Sector'] = 'Healthcare'
df_['Exchange'] = 'NASDAQ'

df_nasdaq = df_nasdaq.append(df_)
df_nasdaq.index = range(len(df_nasdaq))
# Out:
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\2862857503.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\2862857503.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\2862857503.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\2862857503.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\2862857503.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\2862857503.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\2862857503.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\2862857503.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\2862857503.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\2862857503.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\2862857503.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\2862857503.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\2862857503.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\2862857503.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\2862857503.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\2862857503.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\2862857503.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\2862857503.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\2862857503.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\2862857503.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\2862857503.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\2862857503.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\2862857503.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\2862857503.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\2862857503.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\2862857503.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\2862857503.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\2862857503.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\2862857503.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\2862857503.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\2862857503.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\2862857503.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\2862857503.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\2862857503.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\2862857503.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\2862857503.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\2862857503.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\2862857503.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\2862857503.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\2862857503.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\2862857503.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\2862857503.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\2862857503.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\2862857503.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\2862857503.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\2862857503.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\2862857503.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\2862857503.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\2862857503.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\2862857503.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\2862857503.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\2862857503.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\2862857503.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\2862857503.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\2862857503.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\2862857503.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_nasdaq = df_nasdaq.append(df_)

# %%
df_nasdaq.to_csv('nasdaq_ticker.csv',index=False)

# %%
Screener.SectorOption.COMMUNICATION_SERVICES
Screener.SectorOption.CONSUMER_CYCLICAL

# %%
# NASDAQ Communication_Services
options = [Screener.ExchangeOption.NASDAQ, Screener.SectorOption.COMMUNICATION_SERVICES]
screener = Screener(filter_options=options, view_option=Screener.ViewOption.VALUATION,
                    pages=[x for x in range(1, 11)])
# get screener
len_ = len(screener.data_frames)
for i in range(len_):
    if i == 0:
        df = screener.data_frames[i]
    elif i!=1 and screener.data_frames[i].shape[0] > 1:
        df = df.append(screener.data_frames[i])
# create temp list
df_ = pd.DataFrame()
df_['Ticker'] = df.Ticker
df_['Sector'] = 'Communication_Services'
df_['Exchange'] = 'NASDAQ'

df_nasdaq = df_nasdaq.append(df_)
df_nasdaq.index = range(len(df_nasdaq))
# Out:
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\4116831499.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\4116831499.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\4116831499.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\4116831499.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\4116831499.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\4116831499.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\4116831499.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\4116831499.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\4116831499.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_nasdaq = df_nasdaq.append(df_)

# %%
# NASDAQ Consumer_Cyclical
options = [Screener.ExchangeOption.NASDAQ, Screener.SectorOption.CONSUMER_CYCLICAL]
screener = Screener(filter_options=options, view_option=Screener.ViewOption.VALUATION,
                    pages=[x for x in range(1, 16)])
# get screener
len_ = len(screener.data_frames)
for i in range(len_):
    if i == 0:
        df = screener.data_frames[i]
    elif i!=1 and screener.data_frames[i].shape[0] > 1:
        df = df.append(screener.data_frames[i])
# create temp list
df_ = pd.DataFrame()
df_['Ticker'] = df.Ticker
df_['Sector'] = 'Consumer_Cyclical'
df_['Exchange'] = 'NASDAQ'

df_nasdaq = df_nasdaq.append(df_)
df_nasdaq.index = range(len(df_nasdaq))
# Out:
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\4142219669.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\4142219669.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\4142219669.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\4142219669.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\4142219669.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\4142219669.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\4142219669.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\4142219669.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\4142219669.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\4142219669.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\4142219669.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\4142219669.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\4142219669.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\4142219669.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_nasdaq = df_nasdaq.append(df_)

# %%
Screener.SectorOption.CONSUMER_DEFENSIVE

# %%
# NASDAQ Consumer_Defensive
options = [Screener.ExchangeOption.NASDAQ, Screener.SectorOption.CONSUMER_DEFENSIVE]
screener = Screener(filter_options=options, view_option=Screener.ViewOption.VALUATION,
                    pages=[x for x in range(1, 8)])
# get screener
len_ = len(screener.data_frames)
for i in range(len_):
    if i == 0:
        df = screener.data_frames[i]
    elif i!=1 and screener.data_frames[i].shape[0] > 1:
        df = df.append(screener.data_frames[i])
# create temp list
df_ = pd.DataFrame()
df_['Ticker'] = df.Ticker
df_['Sector'] = 'Consumer_Defensive'
df_['Exchange'] = 'NASDAQ'

df_nasdaq = df_nasdaq.append(df_)
df_nasdaq.index = range(len(df_nasdaq))
# Out:
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\3136990430.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\3136990430.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\3136990430.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\3136990430.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\3136990430.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\3136990430.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_nasdaq = df_nasdaq.append(df_)

# %%
df_nasdaq.to_csv('nasdaq_ticker.csv',index=False)

# %%
df_nasdaq.Sector.unique()
# Out:
# array(['Technology', 'Energy', 'Basic_Materials', 'Financial',
#        'Healthcare', 'Communication_Services', 'Consumer_Cyclical',
#        'Consumer_Defensive'], dtype=object)

# %%
df_nasdaq = pd.read_csv('nasdaq_ticker.csv')

# %%
df_nasdaq.Sector.unique()
# Out:
# array(['Technology', 'Energy', 'Basic_Materials', 'Financial',
#        'Healthcare', 'Communication_Services', 'Consumer_Cyclical',
#        'Consumer_Defensive'], dtype=object)

# %%
# NASDAQ Industrials
options = [Screener.ExchangeOption.NASDAQ, Screener.SectorOption.INDUSTRIALS]
screener = Screener(filter_options=options, view_option=Screener.ViewOption.VALUATION,
                    pages=[x for x in range(1, 16)])
# get screener
len_ = len(screener.data_frames)
for i in range(len_):
    if i == 0:
        df = screener.data_frames[i]
    elif i!=1 and screener.data_frames[i].shape[0] > 1:
        df = df.append(screener.data_frames[i])
# create temp list
df_ = pd.DataFrame()
df_['Ticker'] = df.Ticker
df_['Sector'] = 'Industrials'
df_['Exchange'] = 'NASDAQ'

df_nasdaq = df_nasdaq.append(df_)
df_nasdaq.index = range(len(df_nasdaq))
# Out:
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\2742894248.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\2742894248.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\2742894248.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\2742894248.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\2742894248.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\2742894248.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\2742894248.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\2742894248.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\2742894248.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\2742894248.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\2742894248.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\2742894248.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\2742894248.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\2742894248.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_nasdaq = df_nasdaq.append(df_)

# %%
df_nasdaq.Sector.unique()
# Out:
# array(['Technology', 'Energy', 'Basic_Materials', 'Financial',
#        'Healthcare', 'Communication_Services', 'Consumer_Cyclical',
#        'Consumer_Defensive', 'Industrials'], dtype=object)

# %%
# NASDAQ Real_Estate
options = [Screener.ExchangeOption.NASDAQ, Screener.SectorOption.REAL_ESTATE]
screener = Screener(filter_options=options, view_option=Screener.ViewOption.VALUATION,
                    pages=[x for x in range(1, 5)])
# get screener
len_ = len(screener.data_frames)
for i in range(len_):
    if i == 0:
        df = screener.data_frames[i]
    elif i!=1 and screener.data_frames[i].shape[0] > 1:
        df = df.append(screener.data_frames[i])
# create temp list
df_ = pd.DataFrame()
df_['Ticker'] = df.Ticker
df_['Sector'] = 'Real_Estate'
df_['Exchange'] = 'NASDAQ'

df_nasdaq = df_nasdaq.append(df_)
df_nasdaq.index = range(len(df_nasdaq))
# Out:
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\721838373.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\721838373.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\721838373.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_nasdaq = df_nasdaq.append(df_)

# %%
# NASDAQ Utilities
options = [Screener.ExchangeOption.NASDAQ, Screener.SectorOption.UTILITIES]
screener = Screener(filter_options=options, view_option=Screener.ViewOption.VALUATION,
                    pages=[x for x in range(1, 4)])
# get screener
len_ = len(screener.data_frames)
for i in range(len_):
    if i == 0:
        df = screener.data_frames[i]
    elif i!=1 and screener.data_frames[i].shape[0] > 1:
        df = df.append(screener.data_frames[i])
# create temp list
df_ = pd.DataFrame()
df_['Ticker'] = df.Ticker
df_['Sector'] = 'Utilities'
df_['Exchange'] = 'NASDAQ'

df_nasdaq = df_nasdaq.append(df_)
df_nasdaq.index = range(len(df_nasdaq))
# Out:
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\559092568.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_30840\559092568.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_nasdaq = df_nasdaq.append(df_)

# %%
df_nasdaq
# Out:
#      Ticker      Sector Exchange
# 0      AAOI  Technology   NASDAQ
# 1      AAPL  Technology   NASDAQ
# 2      AATC  Technology   NASDAQ
# 3      ABST  Technology   NASDAQ
# 4      ACIW  Technology   NASDAQ
# ...     ...         ...      ...
# 4039    RNW   Utilities   NASDAQ
# 4040    VIA   Utilities   NASDAQ
# 4041   WAVE   Utilities   NASDAQ
# 4042    XEL   Utilities   NASDAQ
# 4043   YORW   Utilities   NASDAQ
#
# [4044 rows x 3 columns]

# %%
df_nasdaq.Sector.unique()
# Out:
# array(['Technology', 'Energy', 'Basic_Materials', 'Financial',
#        'Healthcare', 'Communication_Services', 'Consumer_Cyclical',
#        'Consumer_Defensive', 'Industrials', 'Real_Estate', 'Utilities'],
#       dtype=object)

# %%
df_nasdaq.to_csv('nasdaq_ticker.csv')

# %%
len(df_nasdaq.Ticker.unique())
# Out:
# 4044

# %%
# NASDAQ Energy
options = [Screener.ExchangeOption.NASDAQ, Screener.SectorOption.ENERGY]
screener = Screener(filter_options=options, view_option=Screener.ViewOption.VALUATION,
                    pages=[x for x in range(1, 5)])
# get screener
len_ = len(screener.data_frames)
for i in range(len_):
    if i == 0:
        df = screener.data_frames[i]
    elif i!=1 and screener.data_frames[i].shape[0] > 1:
        df = df.append(screener.data_frames[i])
# create temp list
df_ = pd.DataFrame()
df_['Ticker'] = df.Ticker
df_['Sector'] = 'Energy'
df_['Exchange'] = 'NASDAQ'

df_nasdaq = df_nasdaq.append(df_)
df_nasdaq.index = range(len(df_nasdaq))
