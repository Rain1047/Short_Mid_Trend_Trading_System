# %%
# import libraries
import urllib.request
from urllib.request import urlopen
import urllib.parse
import requests
import pandas as pd
from bs4 import BeautifulSoup
import csv

# %%
headers = {'User-Agent':'Mozilla/5.0 Chrome/103.0.5060.114 Safari/537.36 Edg/103.0.1264.62'}
# html_data = requests.get('https://www.slickcharts.com/nasdaq100',headers=headers)
# soup = BeautifulSoup(html_data.text, 'lxml')

# %%
soup
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <!-- Required meta tags -->
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/>
# <link href="/css/cosmo/bootstrap.min.css" rel="stylesheet"/>
# <link href="https://fonts.googleapis.com/css?family=Open+Sans" rel="stylesheet"/>
# <style>
#         .maxWidth {
#             max-width: 1200px;
#         }
#         body {
#             background-color: #FBFCEA;
#             background-color: rgb(250, 250, 250);
#         }
#     </style>
# <title>Nasdaq 100 Index Component Weights - Nasdaq 100 Companies</title>
# <script>
#     (function(h,o,t,j,a,r){
#         h.hj=h.hj||function(){(h.hj.q=h.hj.q||[]).push(arguments)};
#         h._hjSettings={hjid:845487,hjsv:6};
#         a=o.getElementsByTagName('head')[0];
#         r=o.createElement('script');r.async=1;
#         r.src=t+h._hjSettings.hjid+j+h._hjSettings.hjsv;
#         a.appendChild(r);
# ...

# %%
soup.table
# Out:
# <table class="table table-hover table-borderless table-sm">
# <thead>
# <tr>
# <th scope="col">#</th>
# <th scope="col" style="width: 30%">Company</th>
# <th scope="col">Symbol</th>
# <th scope="col">Weight</th>
# <th scope="col">      Price</th>
# <th scope="col">Chg</th>
# <th scope="col">% Chg</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>1</td>
# <td><a href="/symbol/AAPL">Apple Inc</a></td>
# <td><a href="/symbol/AAPL">AAPL</a></td>
# <td>14.289</td>
# <td class="text-nowrap"><img alt="" src="/img/down.gif"/>   150.05</td>
# <td class="text-nowrap" style="color: red">-0.12</td>
# <td class="text-nowrap" style="color: red">(-0.08%)</td>
# </tr>
# <tr>
# <td>2</td>
# <td><a href="/symbol/MSFT">Microsoft Corp</a></td>
# <td><a href="/symbol/MSFT">MSFT</a></td>
# <td>11.287</td>
# <td class="text-nowrap"><img alt="" src="/img/up.gif"/>   256.78</td>
# <td class="text-nowrap" style="color: green">0.06</td>
# <td class="text-nowrap" style="color: green">(0.02%)</td>
# </tr>
# <tr>
# ...

# %%
tables = soup.find_all('table', attrs={'class':'table'})

# %%
tables[0]
# Out:
# <table class="table table-hover table-borderless table-sm">
# <thead>
# <tr>
# <th scope="col">#</th>
# <th scope="col" style="width: 30%">Company</th>
# <th scope="col">Symbol</th>
# <th scope="col">Weight</th>
# <th scope="col">      Price</th>
# <th scope="col">Chg</th>
# <th scope="col">% Chg</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>1</td>
# <td><a href="/symbol/AAPL">Apple Inc</a></td>
# <td><a href="/symbol/AAPL">AAPL</a></td>
# <td>14.289</td>
# <td class="text-nowrap"><img alt="" src="/img/down.gif"/>   150.05</td>
# <td class="text-nowrap" style="color: red">-0.12</td>
# <td class="text-nowrap" style="color: red">(-0.08%)</td>
# </tr>
# <tr>
# <td>2</td>
# <td><a href="/symbol/MSFT">Microsoft Corp</a></td>
# <td><a href="/symbol/MSFT">MSFT</a></td>
# <td>11.287</td>
# <td class="text-nowrap"><img alt="" src="/img/up.gif"/>   256.78</td>
# <td class="text-nowrap" style="color: green">0.06</td>
# <td class="text-nowrap" style="color: green">(0.02%)</td>
# </tr>
# <tr>
# ...

# %%
target_table = soup.find_all('table', attrs={'class':'table'})[0]

# %%
target_table
# Out:
# <table class="table table-hover table-borderless table-sm">
# <thead>
# <tr>
# <th scope="col">#</th>
# <th scope="col" style="width: 30%">Company</th>
# <th scope="col">Symbol</th>
# <th scope="col">Weight</th>
# <th scope="col">      Price</th>
# <th scope="col">Chg</th>
# <th scope="col">% Chg</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>1</td>
# <td><a href="/symbol/AAPL">Apple Inc</a></td>
# <td><a href="/symbol/AAPL">AAPL</a></td>
# <td>14.289</td>
# <td class="text-nowrap"><img alt="" src="/img/down.gif"/>   150.05</td>
# <td class="text-nowrap" style="color: red">-0.12</td>
# <td class="text-nowrap" style="color: red">(-0.08%)</td>
# </tr>
# <tr>
# <td>2</td>
# <td><a href="/symbol/MSFT">Microsoft Corp</a></td>
# <td><a href="/symbol/MSFT">MSFT</a></td>
# <td>11.287</td>
# <td class="text-nowrap"><img alt="" src="/img/up.gif"/>   256.78</td>
# <td class="text-nowrap" style="color: green">0.06</td>
# <td class="text-nowrap" style="color: green">(0.02%)</td>
# </tr>
# <tr>
# ...

# %%
# create the dataframe
nasdaq_100 = pd.DataFrame(columns=["symbol", "weight"])

for row in target_table.find_all('tr'):
    col = row.find_all('td')
    if len(col) == 7:
        # # index
        # print(col[0].text)
        # # company name
        # print(col[1].text)
        # # ticker symbol
        # print(col[2].text)
        # # ticker weight
        # print(col[3].text)
        # # price
        # print(col[4].text)
        # # chg
        # print(col[5].text)
        # # chg percent
        # print(col[6].text)
        symbol = col[2].text
        weight = col[3].text
        nasdaq_100 = nasdaq_100.append({'symbol':symbol, 'weight':weight},ignore_index=True)
# Out:
# C:\Users\Rain\AppData\Local\Temp\ipykernel_13308\4170139041.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   nasdaq_100 = nasdaq_100.append({'symbol':symbol, 'weight':weight},ignore_index=True)
# C:\Users\Rain\AppData\Local\Temp\ipykernel_13308\4170139041.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   nasdaq_100 = nasdaq_100.append({'symbol':symbol, 'weight':weight},ignore_index=True)
# C:\Users\Rain\AppData\Local\Temp\ipykernel_13308\4170139041.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   nasdaq_100 = nasdaq_100.append({'symbol':symbol, 'weight':weight},ignore_index=True)
# ...

# %%
nasdaq_100
# Out:
#     symbol  weight
# 0     AAPL  14.289
# 1     MSFT  11.287
# 2     AMZN   6.792
# 3     TSLA   4.386
# 4     META   3.325
# ..     ...     ...
# 97    SWKS   0.159
# 98    NTES   0.153
# 99    SPLK    0.15
# 100   OKTA   0.138
# 101   DOCU   0.124
#
# [102 rows x 2 columns]

# %%
table = soup.table

# %%
table

# %%
all_tables = soup.find('table')

# %%
all_tables

# %%
from get_us_index import get_dowjones50

# %%
from get_us_index import get_nasdaq100 
from get_us_index import get_sp500
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\Rain\Dropbox\My PC (DESKTOP-EC6QP18)\Desktop\Trade\scripts\gather_data\get_us_nasdaq_100.ipynb Cell 16 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Rain/Dropbox/My%20PC%20%28DESKTOP-EC6QP18%29/Desktop/Trade/scripts/gather_data/get_us_nasdaq_100.ipynb#ch0000015?line=0'>1</a> from get_us_index import get_nasdaq100
#       <a href='vscode-notebook-cell:/c%3A/Users/Rain/Dropbox/My%20PC%20%28DESKTOP-EC6QP18%29/Desktop/Trade/scripts/gather_data/get_us_nasdaq_100.ipynb#ch0000015?line=1'>2</a> from get_us_index import get_sp500
#
# ModuleNotFoundError: No module named 'get_us_index'

# %%
from get_us_index import get_dowjones50
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# c:\Users\Rain\Dropbox\My PC (DESKTOP-EC6QP18)\Desktop\Trade\scripts\gather_data\get_us_nasdaq_100.ipynb Cell 16 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Rain/Dropbox/My%20PC%20%28DESKTOP-EC6QP18%29/Desktop/Trade/scripts/gather_data/get_us_nasdaq_100.ipynb#ch0000022?line=0'>1</a> from get_us_index import get_dowjones50
#
# ImportError: cannot import name 'get_dowjones50' from 'get_us_index' (c:\Users\Rain\Dropbox\My PC (DESKTOP-EC6QP18)\Desktop\Trade\scripts\gather_data\get_us_index.py)

# %%
# dowjones
def get_dowjones50():
    # define the url
    html_data = requests.get('https://www.slickcharts.com/dowjones',headers=headers)
    # make the soup
    soup = BeautifulSoup(html_data.text, 'lxml')
    # find the right table
    target_table = soup.find_all('table', attrs={'class':'table'})[0]

    # create the dataframe
    dowjones50 = pd.DataFrame(columns=["symbol", "weight"])

    for row in target_table.find_all('tr'):
        col = row.find_all('td')
        if len(col) == 7:
            symbol = col[2].text
            weight = col[3].text
            dowjones50 = dowjones50.append({'symbol':symbol, 'weight':weight},ignore_index=True)
    return dowjones50

# %%
dowjones = get_dowjones50()
# Out:
# C:\Users\Rain\AppData\Local\Temp\ipykernel_28756\1132099841.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dowjones50 = dowjones50.append({'symbol':symbol, 'weight':weight},ignore_index=True)
# C:\Users\Rain\AppData\Local\Temp\ipykernel_28756\1132099841.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dowjones50 = dowjones50.append({'symbol':symbol, 'weight':weight},ignore_index=True)
# C:\Users\Rain\AppData\Local\Temp\ipykernel_28756\1132099841.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dowjones50 = dowjones50.append({'symbol':symbol, 'weight':weight},ignore_index=True)
# ...

# %%
dowjones
# Out:
#    symbol    weight
# 0     UNH  10.80582
# 1      HD   6.22588
# 2      GS  6.056189
# 3    MSFT  5.464528
# 4     MCD  5.432698
# 5    AMGN  5.281933
# 6       V  4.428531
# 7     JNJ   3.77837
# 8     CAT   3.65492
# 9     HON  3.645672
# 10    CRM  3.463506
# 11    TRV  3.348228
# 12   AAPL  3.193162
# 13     BA  3.164772
# 14     PG  3.124339
# 15    IBM   2.99078
# 16    AXP  2.935291
# 17    CVX  2.923677
# 18    MMM  2.759578
# 19    WMT   2.74904
# 20    JPM  2.322769
# 21    NKE  2.219965
# 22    MRK  2.019088
# 23    DIS  1.975214
# 24     KO  1.337313
# 25     VZ  1.085894
# 26    DOW  1.051703
# 27   CSCO  0.910396
# 28   INTC  0.811033
# 29    WBA  0.792752

# %%
# from get_us_index import  get_dowjones50
nasdaq_100 = get_nasdaq100()
sp500 = get_sp500()
dowjones50 = get_dowjones50()
# Out:
# c:\Users\Rain\Dropbox\My PC (DESKTOP-EC6QP18)\Desktop\Trade\scripts\gather_data\get_us_index.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   nasdaq_100 = nasdaq_100.append({'symbol':symbol, 'weight':weight},ignore_index=True)
# c:\Users\Rain\Dropbox\My PC (DESKTOP-EC6QP18)\Desktop\Trade\scripts\gather_data\get_us_index.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   nasdaq_100 = nasdaq_100.append({'symbol':symbol, 'weight':weight},ignore_index=True)
# c:\Users\Rain\Dropbox\My PC (DESKTOP-EC6QP18)\Desktop\Trade\scripts\gather_data\get_us_index.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   nasdaq_100 = nasdaq_100.append({'symbol':symbol, 'weight':weight},ignore_index=True)
# ...

# %%
nasdaq_100
# Out:
#     symbol  weight
# 0     AAPL  14.289
# 1     MSFT  11.287
# 2     AMZN   6.792
# 3     TSLA   4.386
# 4     META   3.325
# ..     ...     ...
# 97    SWKS   0.159
# 98    NTES   0.153
# 99    SPLK    0.15
# 100   OKTA   0.138
# 101   DOCU   0.124
#
# [102 rows x 2 columns]

# %%
sp500
# Out:
#     symbol    weight
# 0     AAPL  7.145571
# 1     MSFT  5.948039
# 2     AMZN  3.029958
# 3    GOOGL  2.078025
# 4     GOOG   1.92386
# ..     ...       ...
# 499     RL  0.013732
# 500   DISH  0.013284
# 501    PVH  0.012285
# 502    NWS   0.00596
# 503   EMBC  0.000004
#
# [504 rows x 2 columns]

# %%
from get_us_index import get

# %%
url = 'https://www.slickcharts.com/nasdaq100'

# %%
headers = {'User-Agent':'Mozilla/5.0 Chrome/103.0.5060.114 Safari/537.36 Edg/103.0.1264.62'}
# specify the url
urlpage =  'https://www.slickcharts.com/nasdaq100' 
print(urlpage)
# query the website and return the html to the variable 'page'
# page = urllib.request.urlopen(urlpage, headers=headers)
page = urllib.request(urlpage, headers=headers)
# parse the html using beautiful soup and store in variable 'soup'
soup = BeautifulSoup(page, 'html.parser')
# find results within table
table = soup.find('table', attrs={'class': 'table'})
results = table.find_all('tr')
print('Number of results', len(results))
# Out:
# https://www.slickcharts.com/nasdaq100
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\Rain\Dropbox\My PC (DESKTOP-EC6QP18)\Desktop\Trade\scripts\gather_data\get_us_nasdaq_100.ipynb Cell 3 in <cell line: 7>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Rain/Dropbox/My%20PC%20%28DESKTOP-EC6QP18%29/Desktop/Trade/scripts/gather_data/get_us_nasdaq_100.ipynb#ch0000002?line=3'>4</a> print(urlpage)
#       <a href='vscode-notebook-cell:/c%3A/Users/Rain/Dropbox/My%20PC%20%28DESKTOP-EC6QP18%29/Desktop/Trade/scripts/gather_data/get_us_nasdaq_100.ipynb#ch0000002?line=4'>5</a> # query the website and return the html to the variable 'page'
#       <a href='vscode-notebook-cell:/c%3A/Users/Rain/Dropbox/My%20PC%20%28DESKTOP-EC6QP18%29/Desktop/Trade/scripts/gather_data/get_us_nasdaq_100.ipynb#ch0000002?line=5'>6</a> # page = urllib.request.urlopen(urlpage, headers=headers)
# ...

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/103.0.5060.114 Safari/537.36 Edg/103.0.1264.62'}
req = urllib.request.Request(url="http://en.wikipedia.org", headers=headers)
# req = urllib.request.Request(url="http://en.wikipedia.org"+pageUrl)
html = urlopen(req)
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File c:\Users\Rain\Anaconda3\envs\.env\lib\urllib\request.py:1346, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1345 try:
# -> 1346     h.request(req.get_method(), req.selector, req.data, headers,
#    1347               encode_chunked=req.has_header('Transfer-encoding'))
#    1348 except OSError as err: # timeout error
#
# File c:\Users\Rain\Anaconda3\envs\.env\lib\http\client.py:1285, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1284 """Send a complete request to the server."""
# -> 1285 self._send_request(method, url, body, headers, encode_chunked)
#
# File c:\Users\Rain\Anaconda3\envs\.env\lib\http\client.py:1331, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1330     body = _encode(body, 'body')
# ...

# %%
import pandas as pd
from get_index_us import get_sp500
sp500 = get_sp500()
sp500.head(50).to_csv('sp500-top50.csv')

# %%
import pandas as pd
from get_index_ch import get_sz50
sz50 = get_sz50()
samples = sz50.sample(2)
samples
# Out:
# login success!
#     updateDate       code code_name
# 11  2022-06-13  sh.600346      恒力石化
# 40  2022-06-13  sh.601857      中国石油
