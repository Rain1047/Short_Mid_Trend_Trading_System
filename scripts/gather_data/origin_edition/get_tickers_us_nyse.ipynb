# %%
# import pyfinance
from pyfinviz.screener import Screener
import pandas as pd

# %%
df_nyse = pd.DataFrame()

# %%
# NYSE Energy
options = [Screener.ExchangeOption.NYSE, Screener.SectorOption.ENERGY]
screener = Screener(filter_options=options, view_option=Screener.ViewOption.VALUATION,
                    pages=[x for x in range(1, 11)])
# get screener
len_ = len(screener.data_frames)
for i in range(len_):
    if i == 0:
        df = screener.data_frames[i]
    elif i!=1 and screener.data_frames[i].shape[0] > 1:
        df = df.append(screener.data_frames[i])
# create temp list
df_ = pd.DataFrame()
df_['Ticker'] = df.Ticker
df_['Sector'] = 'Energy'
df_['Exchange'] = 'NYSE'

df_nyse = df_nyse.append(df_)
df_nyse.index = range(len(df_nyse))
# Out:
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\325269071.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\325269071.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\325269071.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\325269071.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\325269071.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\325269071.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\325269071.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\325269071.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\325269071.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_nyse = df_nyse.append(df_)

# %%
df_nyse
# Out:
#     Ticker  Sector Exchange
# 0       AM  Energy     NYSE
# 1     AMPY  Energy     NYSE
# 2       AR  Energy     NYSE
# 3     ARCH  Energy     NYSE
# 4     AROC  Energy     NYSE
# ..     ...     ...      ...
# 183    WTI  Energy     NYSE
# 184   WTTR  Energy     NYSE
# 185    XOM  Energy     NYSE
# 186   XPRO  Energy     NYSE
# 187    YPF  Energy     NYSE
#
# [188 rows x 3 columns]

# %%
# NYSE Financial
options = [Screener.ExchangeOption.NYSE, Screener.SectorOption.FINANCIAL]
screener = Screener(filter_options=options, view_option=Screener.ViewOption.VALUATION,
                    pages=[x for x in range(1, 110)])
# get screener
len_ = len(screener.data_frames)
for i in range(len_):
    if i == 0:
        df = screener.data_frames[i]
    elif i!=1 and screener.data_frames[i].shape[0] > 1:
        df = df.append(screener.data_frames[i])
# create temp list
df_ = pd.DataFrame()
df_['Ticker'] = df.Ticker
df_['Sector'] = 'Financial'
df_['Exchange'] = 'NYSE'

df_nyse = df_nyse.append(df_)
df_nyse.index = range(len(df_nyse))
# Out:
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\1950105370.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\1950105370.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\1950105370.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\1950105370.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\1950105370.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\1950105370.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\1950105370.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\1950105370.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\1950105370.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\1950105370.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\1950105370.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\1950105370.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\1950105370.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\1950105370.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\1950105370.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\1950105370.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\1950105370.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\1950105370.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\1950105370.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\1950105370.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\1950105370.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\1950105370.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\1950105370.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\1950105370.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\1950105370.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\1950105370.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\1950105370.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\1950105370.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\1950105370.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\1950105370.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\1950105370.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\1950105370.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\1950105370.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\1950105370.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\1950105370.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\1950105370.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\1950105370.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\1950105370.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\1950105370.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\1950105370.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\1950105370.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\1950105370.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\1950105370.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\1950105370.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\1950105370.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\1950105370.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\1950105370.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\1950105370.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\1950105370.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\1950105370.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\1950105370.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\1950105370.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\1950105370.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\1950105370.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\1950105370.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\1950105370.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\1950105370.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\1950105370.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\1950105370.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\1950105370.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\1950105370.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\1950105370.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\1950105370.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\1950105370.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\1950105370.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\1950105370.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\1950105370.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\1950105370.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\1950105370.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\1950105370.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\1950105370.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\1950105370.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\1950105370.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\1950105370.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\1950105370.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\1950105370.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\1950105370.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\1950105370.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\1950105370.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\1950105370.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\1950105370.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\1950105370.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\1950105370.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\1950105370.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\1950105370.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\1950105370.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\1950105370.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\1950105370.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\1950105370.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\1950105370.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\1950105370.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\1950105370.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\1950105370.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\1950105370.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\1950105370.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\1950105370.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\1950105370.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\1950105370.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\1950105370.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\1950105370.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\1950105370.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\1950105370.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\1950105370.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\1950105370.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\1950105370.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\1950105370.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\1950105370.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\1950105370.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_nyse = df_nyse.append(df_)

# %%
# NYSE Healthcare
options = [Screener.ExchangeOption.NYSE, Screener.SectorOption.HEALTHCARE]
screener = Screener(filter_options=options, view_option=Screener.ViewOption.VALUATION,
                    pages=[x for x in range(1, 8)])
# get screener
len_ = len(screener.data_frames)
for i in range(len_):
    if i == 0:
        df = screener.data_frames[i]
    elif i!=1 and screener.data_frames[i].shape[0] > 1:
        df = df.append(screener.data_frames[i])
# create temp list
df_ = pd.DataFrame()
df_['Ticker'] = df.Ticker
df_['Sector'] = 'Healthcare'
df_['Exchange'] = 'NYSE'

df_nyse = df_nyse.append(df_)
df_nyse.index = range(len(df_nyse))
# Out:
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\2606192274.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\2606192274.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\2606192274.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\2606192274.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\2606192274.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\2606192274.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_nyse = df_nyse.append(df_)

# %%
df_nyse.to_csv('nyse_ticker.csv')

# %%
df_nyse = pd.read_csv('nyse_ticker.csv')

# %%
df_nyse.shape
# Out:
# (3313, 5)

# %%
df_nyse.Sector.unique()
# Out:
# array(['Energy', 'Financial', 'Healthcare', 'Industrials', 'Real_Estate',
#        'Technology', 'Utilities'], dtype=object)

# %%
# NYSE Industrials
options = [Screener.ExchangeOption.NYSE, Screener.SectorOption.INDUSTRIALS]
screener = Screener(filter_options=options, view_option=Screener.ViewOption.VALUATION,
                    pages=[x for x in range(1, 18)])
# get screener
len_ = len(screener.data_frames)
for i in range(len_):
    if i == 0:
        df = screener.data_frames[i]
    elif i!=1 and screener.data_frames[i].shape[0] > 1:
        df = df.append(screener.data_frames[i])
# create temp list
df_ = pd.DataFrame()
df_['Ticker'] = df.Ticker
df_['Sector'] = 'Industrials'
df_['Exchange'] = 'NYSE'

df_nyse = df_nyse.append(df_)
df_nyse.index = range(len(df_nyse))
# Out:
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\3084212763.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\3084212763.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\3084212763.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\3084212763.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\3084212763.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\3084212763.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\3084212763.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\3084212763.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\3084212763.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\3084212763.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\3084212763.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\3084212763.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\3084212763.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\3084212763.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\3084212763.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\3084212763.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_nyse = df_nyse.append(df_)

# %%
# NYSE Real_Estate
options = [Screener.ExchangeOption.NYSE, Screener.SectorOption.REAL_ESTATE]
screener = Screener(filter_options=options, view_option=Screener.ViewOption.VALUATION,
                    pages=[x for x in range(1, 12)])
# get screener
len_ = len(screener.data_frames)
for i in range(len_):
    if i == 0:
        df = screener.data_frames[i]
    elif i!=1 and screener.data_frames[i].shape[0] > 1:
        df = df.append(screener.data_frames[i])
# create temp list
df_ = pd.DataFrame()
df_['Ticker'] = df.Ticker
df_['Sector'] = 'Real_Estate'
df_['Exchange'] = 'NYSE'

df_nyse = df_nyse.append(df_)
df_nyse.index = range(len(df_nyse))
# Out:
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\3212702443.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\3212702443.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\3212702443.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\3212702443.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\3212702443.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\3212702443.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\3212702443.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\3212702443.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\3212702443.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\3212702443.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_nyse = df_nyse.append(df_)

# %%
# NYSE Technology
options = [Screener.ExchangeOption.NYSE, Screener.SectorOption.TECHNOLOGY]
screener = Screener(filter_options=options, view_option=Screener.ViewOption.VALUATION,
                    pages=[x for x in range(1, 12)])
# get screener
len_ = len(screener.data_frames)
for i in range(len_):
    if i == 0:
        df = screener.data_frames[i]
    elif i!=1 and screener.data_frames[i].shape[0] > 1:
        df = df.append(screener.data_frames[i])
# create temp list
df_ = pd.DataFrame()
df_['Ticker'] = df.Ticker
df_['Sector'] = 'Technology'
df_['Exchange'] = 'NYSE'

df_nyse = df_nyse.append(df_)
df_nyse.index = range(len(df_nyse))
# Out:
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\2568159099.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\2568159099.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\2568159099.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\2568159099.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\2568159099.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\2568159099.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\2568159099.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\2568159099.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\2568159099.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\2568159099.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_nyse = df_nyse.append(df_)

# %%
df_nyse.to_csv('nyse_ticker.csv')
df_nyse.Sector.unique()
# Out:
# array(['Energy', 'Financial', 'Healthcare', 'Industrials', 'Real_Estate',
#        'Technology', 'Utilities'], dtype=object)

# %%
# NYSE Utilities
options = [Screener.ExchangeOption.NYSE, Screener.SectorOption.UTILITIES]
screener = Screener(filter_options=options, view_option=Screener.ViewOption.VALUATION,
                    pages=[x for x in range(1, 12)])
# get screener
len_ = len(screener.data_frames)
for i in range(len_):
    if i == 0:
        df = screener.data_frames[i]
    elif i!=1 and screener.data_frames[i].shape[0] > 1:
        df = df.append(screener.data_frames[i])
# create temp list
df_ = pd.DataFrame()
df_['Ticker'] = df.Ticker
df_['Sector'] = 'Utilities'
df_['Exchange'] = 'NYSE'

df_nyse = df_nyse.append(df_)
df_nyse.index = range(len(df_nyse))
# Out:
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\3636884719.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\3636884719.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\3636884719.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_904\3636884719.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_nyse = df_nyse.append(df_)

# %%
df_nyse.to_csv('nyse_ticker.csv')
df_nyse.Sector.unique()
# Out:
# array(['Energy', 'Financial', 'Healthcare', 'Industrials', 'Real_Estate',
#        'Technology', 'Utilities'], dtype=object)

# %%
# NYSE Basic_Materials
options = [Screener.ExchangeOption.NYSE, Screener.SectorOption.BASIC_MATERIALS]
screener = Screener(filter_options=options, view_option=Screener.ViewOption.VALUATION,
                    pages=[x for x in range(1, 10)])
# get screener
len_ = len(screener.data_frames)
for i in range(len_):
    if i == 0:
        df = screener.data_frames[i]
    elif i!=1 and screener.data_frames[i].shape[0] > 1:
        df = df.append(screener.data_frames[i])
# create temp list
df_ = pd.DataFrame()
df_['Ticker'] = df.Ticker
df_['Sector'] = 'Basic_Materials'
df_['Exchange'] = 'NYSE'

df_nyse = df_nyse.append(df_)
df_nyse.index = range(len(df_nyse))
# Out:
# C:\Users\Rain\AppData\Local\Temp\ipykernel_3220\3521442006.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_3220\3521442006.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_3220\3521442006.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_3220\3521442006.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_3220\3521442006.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_3220\3521442006.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_3220\3521442006.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_nyse = df_nyse.append(df_)

# %%
# NYSE Communication_Services
options = [Screener.ExchangeOption.NYSE, Screener.SectorOption.COMMUNICATION_SERVICES]
screener = Screener(filter_options=options, view_option=Screener.ViewOption.VALUATION,
                    pages=[x for x in range(1, 6)])
# get screener
len_ = len(screener.data_frames)
for i in range(len_):
    if i == 0:
        df = screener.data_frames[i]
    elif i!=1 and screener.data_frames[i].shape[0] > 1:
        df = df.append(screener.data_frames[i])
# create temp list
df_ = pd.DataFrame()
df_['Ticker'] = df.Ticker
df_['Sector'] = 'Communication_Services'
df_['Exchange'] = 'NYSE'

df_nyse = df_nyse.append(df_)
df_nyse.index = range(len(df_nyse))
# Out:
# C:\Users\Rain\AppData\Local\Temp\ipykernel_3220\2534040233.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_3220\2534040233.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_3220\2534040233.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_3220\2534040233.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_nyse = df_nyse.append(df_)

# %%
# NYSE Consumer_Defensive
options = [Screener.ExchangeOption.NYSE, Screener.SectorOption.CONSUMER_DEFENSIVE]
screener = Screener(filter_options=options, view_option=Screener.ViewOption.VALUATION,
                    pages=[x for x in range(1, 7)])
# get screener
len_ = len(screener.data_frames)
for i in range(len_):
    if i == 0:
        df = screener.data_frames[i]
    elif i!=1 and screener.data_frames[i].shape[0] > 1:
        df = df.append(screener.data_frames[i])
# create temp list
df_ = pd.DataFrame()
df_['Ticker'] = df.Ticker
df_['Sector'] = 'Consumer_Defensive'
df_['Exchange'] = 'NYSE'

df_nyse = df_nyse.append(df_)
df_nyse.index = range(len(df_nyse))
# Out:
# C:\Users\Rain\AppData\Local\Temp\ipykernel_3220\160819659.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_3220\160819659.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_3220\160819659.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_3220\160819659.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_3220\160819659.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_nyse = df_nyse.append(df_)

# %%
# NYSE Consumer_Cyclical
options = [Screener.ExchangeOption.NYSE, Screener.SectorOption.CONSUMER_CYCLICAL]
screener = Screener(filter_options=options, view_option=Screener.ViewOption.VALUATION,
                    pages=[x for x in range(1, 15)])
# get screener
len_ = len(screener.data_frames)
for i in range(len_):
    if i == 0:
        df = screener.data_frames[i]
    elif i!=1 and screener.data_frames[i].shape[0] > 1:
        df = df.append(screener.data_frames[i])
# create temp list
df_ = pd.DataFrame()
df_['Ticker'] = df.Ticker
df_['Sector'] = 'Consumer_Cyclical'
df_['Exchange'] = 'NYSE'

df_nyse = df_nyse.append(df_)
df_nyse.index = range(len(df_nyse))
# Out:
# C:\Users\Rain\AppData\Local\Temp\ipykernel_3220\1148795061.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_3220\1148795061.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_3220\1148795061.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_3220\1148795061.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_3220\1148795061.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_3220\1148795061.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_3220\1148795061.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_3220\1148795061.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_3220\1148795061.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_3220\1148795061.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_3220\1148795061.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_3220\1148795061.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(screener.data_frames[i])
# C:\Users\Rain\AppData\Local\Temp\ipykernel_3220\1148795061.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_nyse = df_nyse.append(df_)

# %%
df_nyse.to_csv('nyse_ticker.csv')
df_nyse.Sector.unique()
# Out:
# array(['Energy', 'Financial', 'Healthcare', 'Industrials', 'Real_Estate',
#        'Technology', 'Utilities', 'Basic_Materials',
#        'Communication_Services', 'Consumer_Defensive',
#        'Consumer_Cyclical'], dtype=object)

# %%
df_nyse = pd.read_csv('nyse_ticker.csv')

# %%
df_nyse.drop(columns={'Unnamed: 0.2','Unnamed: 0.1','Unnamed: 0'},inplace=True)

# %%
df_nyse.to_csv('nyse_ticker.csv')

# %%
df_ = pd.DataFrame()

# %%
df
# Out:
#      No Ticker MarketCap     PE  FwdPE   PEG    PS    PB     PC    PFCF  \
# 0     1    AAP    11.09B  20.23  11.82  1.34  1.00  3.83  79.93   99.70
# 1     2    ABG     3.70B   5.08   5.05  0.27  0.32  1.71  12.45    2.76
# 2     3   ACEL   995.96M  22.03   9.50  1.01  1.27  5.99   4.39   12.99
# 3     4   ADNT     2.63B   3.61   7.53  0.13  0.20  1.17   2.35       -
# 4     5    AEO     2.01B   6.92   6.85  1.96  0.40  1.44   8.80       -
# ..  ...    ...       ...    ...    ...   ...   ...   ...    ...     ...
# 1   262   YETI     4.04B  19.54  13.12  1.41  2.77  8.96  40.29   94.43
# 2   263    YSG   812.88M      -      -     -  1.03  1.52   1.74       -
# 3   264    YUM    33.36B  21.16  21.52  2.18  5.02     -  91.41   41.65
# 4   265   YUMC    18.95B  22.66  24.73  2.27  1.90  2.79   5.16  498.62
# 5   266    ZGN     2.53B      -      -     -  1.93  4.13   3.11   12.36
#
#     EPSthisY  EPSnextY EPSpast5Y EPSnext5Y Salespast5Y   Price  Change  \
# 0     33.70%    12.78%     9.00%    15.15%       2.80%  181.75  -0.63%
# 1    100.90%    -7.53%    29.10%    18.50%       8.50%  163.69  -4.41%
# 2     28.00%    17.10%         -    21.74%           -   10.73  -2.01%
# 3    298.50%  1908.56%    22.00%    28.60%      -4.00%   28.27  -5.89%
# 4    261.60%    30.03%    11.90%     3.54%       6.80%   11.86   1.11%
# ..       ...       ...       ...       ...         ...     ...     ...
# 1     35.20%    20.14%    33.10%    13.87%      11.50%   45.78  -2.95%
# 2     61.30%    36.80%         -         -           -    2.04   0.99%
# 3     77.10%    15.66%    15.40%     9.70%       0.70%  116.54  -0.63%
# 4     17.00%   104.26%    11.10%    10.00%       6.80%   45.10  -6.64%
# 5   -168.90%         -         -         -           -   10.42  -2.43%
#
#         Volume
# 0      605,585
# 1      118,917
# 2      143,855
# 3    1,091,897
# 4    6,388,830
# ..         ...
# 1      816,616
# 2   13,188,773
# 3      825,299
# 4    2,661,274
# 5       83,113
#
# [266 rows x 18 columns]

# %%
df_ = df_nyse['Ticker','Sector','Exchange']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Rain\Anaconda3\envs\.env\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File c:\Users\Rain\Anaconda3\envs\.env\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\Rain\Anaconda3\envs\.env\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('Ticker', 'Sector', 'Exchange')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# c:\Users\Rain\Dropbox\My PC (DESKTOP-EC6QP18)\Desktop\futu_trade\get_tickers_us_nyse.ipynb Cell 24 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Rain/Dropbox/My%20PC%20%28DESKTOP-EC6QP18%29/Desktop/futu_trade/get_tickers_us_nyse.ipynb#ch0000029?line=0'>1</a> df_ = df_nyse['Ticker','Sector','Exchange']
#
# File c:\Users\Rain\Anaconda3\envs\.env\lib\site-packages\pandas\core\frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File c:\Users\Rain\Anaconda3\envs\.env\lib\site-packages\pandas\core\indexes\base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: ('Ticker', 'Sector', 'Exchange')
