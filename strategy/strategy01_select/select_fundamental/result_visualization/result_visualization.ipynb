# %%
import plotly as pt
import pandas as pd 
import numpy as np
import json
import os
import plotly.express as px
import plotly.graph_objects as go

# %%
eps_19_03_a = pd.read_csv('../results_test/eps_test_result_eps_19_03_a.csv')
eps_19_06_a = pd.read_csv('../results_test/eps_test_result_eps_19_06_a.csv')
eps_19_09_a = pd.read_csv('../results_test/eps_test_result_eps_19_09_a.csv')
eps_19_12_a = pd.read_csv('../results_test/eps_test_result_eps_19_12_a.csv')
eps_20_03_a = pd.read_csv('../results_test/eps_test_result_eps_20_03_a.csv')
eps_20_06_a = pd.read_csv('../results_test/eps_test_result_eps_20_06_a.csv')
eps_20_09_a = pd.read_csv('../results_test/eps_test_result_eps_20_09_a.csv')
eps_20_12_a = pd.read_csv('../results_test/eps_test_result_eps_20_12_a.csv')
eps_21_03_a = pd.read_csv('../results_test/eps_test_result_eps_21_03_a.csv')
eps_21_06_a = pd.read_csv('../results_test/eps_test_result_eps_21_06_a.csv')
eps_21_09_a = pd.read_csv('../results_test/eps_test_result_eps_21_09_a.csv')
eps_21_12_a = pd.read_csv('../results_test/eps_test_result_eps_21_12_a.csv')

eps_19_03_b = pd.read_csv('../results_test/eps_test_result_eps_19_03_b.csv')
eps_19_06_b = pd.read_csv('../results_test/eps_test_result_eps_19_06_b.csv')
eps_19_09_b = pd.read_csv('../results_test/eps_test_result_eps_19_09_b.csv')
eps_19_12_b = pd.read_csv('../results_test/eps_test_result_eps_19_12_b.csv')
eps_20_03_b = pd.read_csv('../results_test/eps_test_result_eps_20_03_b.csv')
eps_20_06_b = pd.read_csv('../results_test/eps_test_result_eps_20_06_b.csv')
eps_20_09_b = pd.read_csv('../results_test/eps_test_result_eps_20_09_b.csv')
eps_20_12_b = pd.read_csv('../results_test/eps_test_result_eps_20_12_b.csv')
eps_21_03_b = pd.read_csv('../results_test/eps_test_result_eps_21_03_b.csv')
eps_21_06_b = pd.read_csv('../results_test/eps_test_result_eps_21_06_b.csv')
eps_21_09_b = pd.read_csv('../results_test/eps_test_result_eps_21_09_b.csv')
eps_21_12_b = pd.read_csv('../results_test/eps_test_result_eps_21_12_b.csv')

# %%
res_list = [    eps_19_03_a, eps_19_06_a, eps_19_09_a, eps_19_12_a,
                eps_20_03_a, eps_20_06_a, eps_20_09_a, eps_20_12_a,
                eps_21_03_a, eps_21_06_a, eps_21_09_a, eps_21_12_a,
                eps_19_03_b, eps_19_06_b, eps_19_09_b, eps_19_12_b,
                eps_20_03_b, eps_20_06_b, eps_20_09_b, eps_20_12_b,
                eps_21_03_b, eps_21_06_b, eps_21_09_b, eps_21_12_b
                ]

res_name_list =['eps_19_03_a', 'eps_19_06_a', 'eps_19_09_a', 'eps_19_12_a',
                'eps_20_03_a', 'eps_20_06_a', 'eps_20_09_a', 'eps_20_12_a',
                'eps_21_03_a', 'eps_21_06_a', 'eps_21_09_a', 'eps_21_12_a',
                'eps_19_03_b', 'eps_19_06_b', 'eps_19_09_b', 'eps_19_12_b',
                'eps_20_03_b', 'eps_20_06_b', 'eps_20_09_b', 'eps_20_12_b',
                'eps_21_03_b', 'eps_21_06_b', 'eps_21_09_b', 'eps_21_12_b'
                ]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Rain\Dropbox\My PC (DESKTOP-EC6QP18)\Desktop\trade_repo\strategy\strategy01_select\select_fundamental\result_visualization\result_visualization.ipynb Cell 4 in <cell line: 1>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Rain/Dropbox/My%20PC%20%28DESKTOP-EC6QP18%29/Desktop/trade_repo/strategy/strategy01_select/select_fundamental/result_visualization/result_visualization.ipynb#X13sZmlsZQ%3D%3D?line=0'>1</a> res_list = [    eps_19_03_a, eps_19_06_a, eps_19_09_a, eps_19_12_a,
#       <a href='vscode-notebook-cell:/c%3A/Users/Rain/Dropbox/My%20PC%20%28DESKTOP-EC6QP18%29/Desktop/trade_repo/strategy/strategy01_select/select_fundamental/result_visualization/result_visualization.ipynb#X13sZmlsZQ%3D%3D?line=1'>2</a>                 eps_20_03_a, eps_20_06_a, eps_20_09_a, eps_20_12_a,
# ...

# %%
str1 = 'eps_19_03_a'
str1 = str1[4:]
str1
# Out:
# '19_03_a'

# %%
if not os.path.exists("results_plot"):
    os.mkdir("results_plot")

# %%
df = eps_19_03_a
# drop the 0 line
df = df[df.apply(np.sum,axis=1)!=0]
# df = df.profit_avg_60
fig = px.histogram(df, x="profit_avg_60")
# fig.show()
df[df.profit_avg_60 > 0.06].profit_avg_60.count(),df[df.profit_avg_90 > 0.06].profit_avg_60.count(),df[df.profit_avg_120 > 0.06].profit_avg_60.count(),len(df)
# Out:
# (2121, 2325, 2371, 2626)

# %%
ind = 0
for res in res_list:
    res = res[res.apply(np.sum,axis=1)!=0]
    res_name = res_name_list[ind][4:] 
    fig1 = go.Figure()
    fig1.add_trace(
        go.Histogram(
            x = res.profit_avg_60.values, 
            name = '60 Avg Profit', 
            marker_color = '#FFD700',
            opacity = 1,
        )
    )
    fig1.add_trace(
        go.Histogram(
            x = res.profit_avg_90.values, 
            name = '90 Avg Profit', 
            marker_color = '#4682B4',
            opacity = 0.8,
        )
    )
    fig1.add_trace(
        go.Histogram(
            x = res.profit_avg_120.values, 
            name = '120 Avg Profit', 
            marker_color = '#d14e4e',
            opacity = 0.6,
        )
    )
    fig1.update_layout(
            title_text='{} Profit Distribution'.format(res_name), # title of plot
            xaxis_title_text='Profit Rate', # xaxis label
            yaxis_title_text='Count', # yaxis label
            width=1080,
            # height=540,
            bargap=0.2, # gap between bars of adjacent location coordinates
            bargroupgap=0.1, # gap between bars of the same location coordinates
            barmode='overlay',
            template="gridon",)
    fig1.show()

    fig2 = go.Figure()
    fig2.add_trace(
        go.Histogram(
            x = res.profit_avg_60.values, 
            name = '60 Avg Profit', 
            marker_color = '#FFD700',
            opacity = 1,
        )
    )
    fig2.add_trace(
        go.Histogram(
            x = res.profit_avg_90.values, 
            name = '90 Avg Profit', 
            marker_color = '#4682B4',
            opacity = 0.8,
        )
    )
    fig2.update_layout(
            title_text='{} Profit Distribution'.format(res_name), # title of plot
            xaxis_title_text='Profit Rate', # xaxis label
            yaxis_title_text='Count', # yaxis label
            width=1080,
            # height=540,
            bargap=0.2, # gap between bars of adjacent location coordinates
            bargroupgap=0.1, # gap between bars of the same location coordinates
            barmode='overlay',
            template="gridon",)

    fig3 = go.Figure()
    fig3.add_trace(
        go.Histogram(
            x = res.profit_avg_60.values, 
            name = '60 Avg Profit', 
            marker_color = '#FFD700',
            opacity = 1,
        )
    )
    fig3.add_trace(
        go.Histogram(
            x = res.profit_avg_120.values, 
            name = '120 Avg Profit', 
            marker_color = '#d14e4e',
            opacity = 0.6,
        )
    )
    fig3.update_layout(
            title_text='{} Profit Distribution'.format(res_name), # title of plot
            xaxis_title_text='Profit Rate', # xaxis label
            yaxis_title_text='Count', # yaxis label
            width=1080,
            # height=540,
            bargap=0.2, # gap between bars of adjacent location coordinates
            bargroupgap=0.1, # gap between bars of the same location coordinates
            barmode='overlay',
            template="gridon",)

    fig4 = go.Figure()
    fig4.add_trace(
        go.Histogram(
            x = res.profit_avg_90.values, 
            name = '90 Avg Profit', 
            marker_color = '#4682B4',
            opacity = 0.8,
        )
    )
    fig4.add_trace(
        go.Histogram(
            x = res.profit_avg_120.values, 
            name = '120 Avg Profit', 
            marker_color = '#d14e4e',
            opacity = 0.6,
        )
    )
    fig4.update_layout(
            title_text='{} Profit Distribution'.format(res_name), # title of plot
            xaxis_title_text='Profit Rate', # xaxis label
            yaxis_title_text='Count', # yaxis label
            width=1080,
            # height=540,
            bargap=0.2, # gap between bars of adjacent location coordinates
            bargroupgap=0.1, # gap between bars of the same location coordinates
            barmode='overlay',
            template="gridon",)
    fig1.write_image("results_plot/{}_fig1.png".format(res_name))
    fig2.write_image("results_plot/{}_fig2.png".format(res_name))
    fig3.write_image("results_plot/{}_fig3.png".format(res_name))
    fig4.write_image("results_plot/{}_fig4.png".format(res_name))
    ind += 1

# %%
fig2 = go.Figure()
fig2.add_trace(
    go.Histogram(
        x = df.profit_avg_60.values, 
        name = '60 Avg Profit', 
        marker_color = '#FFD700',
        opacity = 0.9,
    )
)
fig2.add_trace(
    go.Histogram(
        x = df.decline_avg_60.values, 
        name = '60 Avg Decline', 
        marker_color = '#FFD700',
        opacity = 0.9,
    )
)
fig2.update_layout(
        title_text='60 Day Profit&Decline Distribution', # title of plot
        xaxis_title_text='Profit', # xaxis label
        yaxis_title_text='Count', # yaxis label
        bargap=0.2, # gap between bars of adjacent location coordinates
        bargroupgap=0.1, # gap between bars of the same location coordinates
        barmode='overlay',
        template="gridon",)
fig2.show()

# %%
pt.offline.plot(fig1, filename='fig1.html')
# Out:
# 'fig1.html'

# %%
df.profit_avg_60.describe()['mean'],df.profit_avg_90.describe()['mean'],df.profit_avg_120.describe()['mean']
# Out:
# (0.11871922084112242, 0.1338348551394294, 0.15921761705128049)

# %%
df.decline_avg_60.describe()['mean'], df.declince_avg_90.describe()['mean'], df.decline_avg_120.describe()['mean']
# Out:
# (-0.056223989664233955, -0.06719434341896063, -0.07361991725517673)
